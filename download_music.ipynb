# %%
import os
from utils.download_audio import download_and_convert_to_mp3

# Folder name to save the output
output_folder = 'mp3'
os.makedirs(output_folder, exist_ok=True)

urls = ['VV2rGPHvB8g',
        'nMtFJodlIXo',
        '-HlEAEqps9c',
        '-P-Q2t-Snu8',
        'iD90UbVXZSE',
        'tlxVZpNbeAU',
        "9A4_GnALZd4",
        "9w4NgLxN75E"]

for url in urls:
    download_and_convert_to_mp3(url, output_folder)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VV2rGPHvB8g
# [youtube] VV2rGPHvB8g: Downloading webpage
# [youtube] VV2rGPHvB8g: Downloading tv client config
# [youtube] VV2rGPHvB8g: Downloading player b191cf34
# [youtube] VV2rGPHvB8g: Downloading tv player API JSON
# [youtube] VV2rGPHvB8g: Downloading ios player API JSON
# [youtube] VV2rGPHvB8g: Downloading m3u8 information
# MP3 file already exists: mp3/יהודת רביץ - לקחת את ידי בידך.mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nMtFJodlIXo
# [youtube] nMtFJodlIXo: Downloading webpage
# [youtube] nMtFJodlIXo: Downloading tv client config
# [youtube] nMtFJodlIXo: Downloading player b191cf34
# [youtube] nMtFJodlIXo: Downloading tv player API JSON
# [youtube] nMtFJodlIXo: Downloading ios player API JSON
# [youtube] nMtFJodlIXo: Downloading m3u8 information
# MP3 file already exists: mp3/שיר עד - צדיק כתמר - מילים： מהמקורות (תהלים) ｜ לחן： אמיתי נאמן ｜ ביצוע： לא ידוע.mp3
# ...
